# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("C:/Users/jrtan/Data Science Project/Data-Mining-Practice/Fitness_trackers_updated.csv")
y = data["Reviews"]

# %%
print(data)
# Out:
#      Brand Name  Device Type      Model Name               Color  \
# 0        Xiaomi  FitnessBand    Smart Band 5               Black
# 1        Xiaomi  FitnessBand    Smart Band 4               Black
# 2        Xiaomi  FitnessBand        HMSH01GE               Black
# 3        Xiaomi  FitnessBand    Smart Band 5               Black
# 4        Xiaomi  FitnessBand          Band 3               Black
# ..          ...          ...             ...                 ...
# 605  Fire-Boltt   Smartwatch  Talk Bluetooth  Black, Grey, Green
# 606  Fire-Boltt   Smartwatch        Almighty              Orange
# 607  Fire-Boltt   Smartwatch         Mercury                 Red
# 608  Fire-Boltt   Smartwatch            Spin               White
# 609  Fire-Boltt   Smartwatch       Ninja Pro               White
#
#     Selling Price Original Price          Display  Rating (Out of 5)  \
# 0           2,499          2,999   AMOLED Display                4.1
# ...

# %%
data.head()
# Out:
#   Brand Name  Device Type    Model Name  Color Selling Price Original Price  \
# 0     Xiaomi  FitnessBand  Smart Band 5  Black         2,499          2,999
# 1     Xiaomi  FitnessBand  Smart Band 4  Black         2,099          2,499
# 2     Xiaomi  FitnessBand      HMSH01GE  Black         1,722          2,099
# 3     Xiaomi  FitnessBand  Smart Band 5  Black         2,469          2,999
# 4     Xiaomi  FitnessBand        Band 3  Black         1,799          2,199
#
#           Display  Rating (Out of 5)              Strap Material  \
# 0  AMOLED Display                4.1  Thermoplastic polyurethane
# 1  AMOLED Display                4.2  Thermoplastic polyurethane
# 2     LCD Display                3.5                     Leather
# 3  AMOLED Display                4.1  Thermoplastic polyurethane
# 4    OLED Display                4.3                     Plastic
#
#    Average Battery Life (in days) Reviews
# 0                              14     NaN
# ...

# %%
data.tail(10)
# Out:
#      Brand Name Device Type       Model Name                          Color  \
# 600  Fire-Boltt  Smartwatch  SpO2 Full Touch  Black, Blue, Grey, Pink, Gold
# 601  Fire-Boltt  Smartwatch              Max             Black, Blue, Green
# 602  Fire-Boltt  Smartwatch    AI-BT Calling        Black, Blue, Grey, Pink
# 603  Fire-Boltt  Smartwatch           BSW004                          Green
# 604  Fire-Boltt  Smartwatch             Spin               Blue, Grey, Pink
# 605  Fire-Boltt  Smartwatch   Talk Bluetooth             Black, Grey, Green
# 606  Fire-Boltt  Smartwatch         Almighty                         Orange
# 607  Fire-Boltt  Smartwatch          Mercury                            Red
# 608  Fire-Boltt  Smartwatch             Spin                          White
# 609  Fire-Boltt  Smartwatch        Ninja Pro                          White
#
#     Selling Price Original Price          Display  Rating (Out of 5)  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Brand Name                      610 non-null    object
#  1   Device Type                     610 non-null    object
#  2   Model Name                      610 non-null    object
#  3   Color                           610 non-null    object
#  4   Selling Price                   610 non-null    object
#  5   Original Price                  610 non-null    object
#  6   Display                         610 non-null    object
#  7   Rating (Out of 5)               554 non-null    float64
#  8   Strap Material                  610 non-null    object
#  9   Average Battery Life (in days)  610 non-null    int64
#  10  Reviews                         114 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 52.5+ KB

# %%
len(data)
# Out:
# 610

# %%
len(data.columns)
# Out:
# 11

# %%
sns.histplot(data=data, fill=False)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
for display in data['Display']:
    print(display)
# Out:
# AMOLED Display
# AMOLED Display
# LCD Display
# AMOLED Display
# OLED Display
# OLED Display
# OLED Display
# AMOLED Display
# AMOLED Display
# OLED Display
# AMOLED Display
# AMOLED Display
# AMOLED Display
# AMOLED Display
# AMOLED Display
# PMOLED Display
# LED Display
# PMOLED Display
# AMOLED Display
# PMOLED Display
# AMOLED Display
# OLED Display
# LED Display
# LED Display
# OLED Display
# AMOLED Display
# LCD Display
# AMOLED Display
# LCD Display
# LCD Display
# AMOLED Display
# AMOLED Display
# LCD Display
# PMOLED Display
# OLED Display
# LCD Display
# LCD Display
# LCD Display
# LCD Display
# OLED Display
# PMOLED Display
# AMOLED Display
# LCD Display
# AMOLED Display
# AMOLED Display
# OLED Display
# OLED Display
# OLED Display
# AMOLED Display
# OLED Display
# AMOLED Display
# PMOLED Display
# AMOLED Display
# AMOLED Display
# LCD Display
# OLED Display
# PMOLED Display
# PMOLED Display
# PMOLED Display
# PMOLED Display
# PMOLED Display
# LED Display
# LED Display
# ...

# %%
sns.displot(data=data, kind="kde")

# %%
plt.figure(figsize=(12,12))
correlation = data.corr()
sns.heatmap(correlation, annot=True, cmap=plt.cm.PuBu)
plt.show()
